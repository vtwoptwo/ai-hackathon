# %%
import pandas as pd

# %%
df_ground_truth = pd.read_csv('/Users/vtwoptwo/Desktop/docs/robotics_club/hackathons/ai-hackathon/data_0611/ground_truth_0611.csvx')

# %%
df = pd.read_csv('/Users/vtwoptwo/Desktop/docs/robotics_club/hackathons/ai-hackathon/final_csvs.csv')

# %%
df= df.rename(columns={'name': 'File name'})

# %%
accuracy_test = df

# %%
df_ground_truth.head()
# Out:
#                                            File name          Isin Issuer  \
# 0  AB3ZFW - RBC 18-Month EUR Twin Win Autocallabl...  XS1878076543    RBC
# 1  AB5P75 - BNP 2-Year USD Bonus Certificate Wors...  XS2490610263    BNP
# 2  AB5PFT - BNP 2-Year USD Bonus Certificate Wors...  XS2490618670    BNP
# 3  EU2320735_20230302_XS2566031444_Decentia-USD-C...  XS2566031444   Citi
# 4                                   XS2021832634.pdf  XS2021832634    BNP
#
#    Ccy Underlying(s) Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8    Strike  \
# 0  EUR           GLE        NaN        NaN        NaN        NaN    33.164
# 1  USD          SX5E        UKX        SPX        NaN        NaN  4229.530
# 2  USD          SX5E        SMI        SPX        NaN        NaN  4096.540
# 3  USD           RTY       SXXP        NaN        NaN        NaN  1902.659
# 4  USD          SX5E        UKX        SPX        NaN        NaN  4209.630
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13 Launch Date  \
# ...

# %%
accuracy_test['type'] = 'test'
df_ground_truth['type'] = 'ground_truth'

df_concatted = pd.concat([accuracy_test, df_ground_truth])

# %%
df_concatted
# Out:
#     Unnamed: 0                                          File name  \
# 0          0.0                                   XS2444480540.pdf
# 1          1.0                                   XS2424913601.pdf
# 2          2.0                                   XS2474851479.pdf
# 3          3.0                                   XS2033997748.pdf
# 4          4.0                  XS2565974388_USD-TwinWin-18M-.pdf
# 5          5.0                                   XS2439264677.pdf
# 6          6.0  AB5PFT - BNP 2-Year USD Bonus Certificate Wors...
# 7          7.0                                   XS2493928639.pdf
# 8          8.0                                   XS2317910607.pdf
# 9          9.0  AB3ZFW - RBC 18-Month EUR Twin Win Autocallabl...
# 10        10.0  XS2575193920 (TS) - 5y USD Autocallable Note o...
# 11        11.0                                   XS2472707103.pdf
# 12        12.0                                   XS2355961215.pdf
# ...

# %%
accuracy_test
# Out:
#     Unnamed: 0                                          File name  \
# 0            0                                   XS2444480540.pdf
# 1            1                                   XS2424913601.pdf
# 2            2                                   XS2474851479.pdf
# 3            3                                   XS2033997748.pdf
# 4            4                  XS2565974388_USD-TwinWin-18M-.pdf
# 5            5                                   XS2439264677.pdf
# 6            6  AB5PFT - BNP 2-Year USD Bonus Certificate Wors...
# 7            7                                   XS2493928639.pdf
# 8            8                                   XS2317910607.pdf
# 9            9  AB3ZFW - RBC 18-Month EUR Twin Win Autocallabl...
# 10          10  XS2575193920 (TS) - 5y USD Autocallable Note o...
# 11          11                                   XS2472707103.pdf
# 12          12                                   XS2355961215.pdf
# ...
